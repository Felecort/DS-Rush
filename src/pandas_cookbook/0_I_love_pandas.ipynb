# %%
import pandas as pd
import numpy as np

# %%
students_performance = pd.read_csv(
    "https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv")

# %%
students_performance.head(8)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# ...

# %%
students_performance.tail(8)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# ...

# %%
students_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
students_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
students_performance.shape
# Out:
# (1000, 8)

# %%
students_performance.size
# Out:
# 8000

# %%
students_performance.groupby("gender").aggregate({"writing score": "mean"})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
students_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# First five rows and first three colomns
students_performance.iloc[0:5, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
students_performance.iloc[[0, 2, 4, 6], [0, 3, 6, -1]]
# Out:
#    gender     lunch  reading score  writing score
# 0  female  standard             72             74
# 2  female  standard             95             93
# 4    male  standard             78             75
# 6  female  standard             95             92

# %%
s_p_with_names = students_performance.iloc[[0, 3, 4, 7, 8]]
s_p_with_names
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44
# 4                    none          76             78             75
# 7                    none          40             43             39
# 8               completed          64             64             67

# %%
s_p_with_names.index = ("Bob", "John", "Ioan", "Levi", "Siegward")
s_p_with_names
# Out:
#           gender race/ethnicity parental level of education         lunch  \
# Bob       female        group B           bachelor's degree      standard
# John        male        group A          associate's degree  free/reduced
# Ioan        male        group C                some college      standard
# Levi        male        group B                some college  free/reduced
# Siegward    male        group D                 high school  free/reduced
#
#          test preparation course  math score  reading score  writing score
# Bob                         none          72             72             74
# John                        none          47             57             44
# Ioan                        none          76             78             75
# Levi                        none          40             43             39
# Siegward               completed          64             64             67

# %%
s_p_with_names.loc[["Bob", "Levi"], ["gender", "lunch"]]
# Out:
#       gender         lunch
# Bob   female      standard
# Levi    male  free/reduced

# %%
print(type(s_p_with_names))
print(type(s_p_with_names.iloc[:, 1]))
s_p_with_names.iloc[:, 1]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# Bob         group B
# John        group A
# Ioan        group C
# Levi        group B
# Siegward    group D
# Name: race/ethnicity, dtype: object

# %%
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1, 2, 3], index=["Bob", "John", "Ioan"])
# Out:
# Bob     1
# John    2
# Ioan    3
# dtype: int64

# %% [markdown]
# Pd.DataFrame = [pd.Seriece, pd.Seriece, pd.Seriece...]

# %%
# The same indexes
series_1 = pd.Series([1, 2, 3], index=["Bob", "John", "Ioan"])
series_2 = pd.Series([4, 5, 6], index=["Bob", "John", "Ioan"])
pd.DataFrame({"col_name_1":series_1, "col_name_2": series_2})
# Out:
#       col_name_1  col_name_2
# Bob            1           4
# John           2           5
# Ioan           3           6

# %%
# Other indexes
series_1 = pd.Series([1, 2, 3], index=["Bob", "John", "Ioan"])
series_2 = pd.Series([4, 5, 6], index=["Bob", "Bill", "Ioan"])
pd.DataFrame({"col_name_1":series_1, "col_name_2": series_2})
# Out:
#       col_name_1  col_name_2
# Bill         NaN         5.0
# Bob          1.0         4.0
# Ioan         3.0         6.0
# John         2.0         NaN

# %%
# pd.Series
s_p_with_names["gender"]
# Out:
# Bob         female
# John          male
# Ioan          male
# Levi          male
# Siegward      male
# Name: gender, dtype: object

# %%
# pd.DataFrame
s_p_with_names[["gender"]]
# Out:
#           gender
# Bob       female
# John        male
# Ioan        male
# Levi        male
# Siegward    male

# %%
s_p_with_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Bob to Siegward
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       5 non-null      object
#  1   race/ethnicity               5 non-null      object
#  2   parental level of education  5 non-null      object
#  3   lunch                        5 non-null      object
#  4   test preparation course      5 non-null      object
#  5   math score                   5 non-null      int64
#  6   reading score                5 non-null      int64
#  7   writing score                5 non-null      int64
# dtypes: int64(3), object(5)
# memory usage: 532.0+ bytes

# %%
titanic = pd.read_csv("https://stepik.org/media/attachments/course/4852/titanic.csv")

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
